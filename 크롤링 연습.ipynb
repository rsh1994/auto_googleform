# %%
from bs4 import BeautifulSoup
import  pandas  as  pd
import requests 
import re

# %%
url = 'https://kin.naver.com/search/list.nhn?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC'

response = requests.get(url)

if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    title = soup.select_one('#s_content > div.section > ul > li:nth-child(1) > dl > dt > a')
    print(title)
    print(title.get_text())

else : 
    print(response.status_code)
# Out:
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=111&amp;docId=399905207&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin&amp;rank=1&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b>강좌 질문있어요</a>
# 파이썬강좌 질문있어요

# %%
url = 'https://www.nike.com/kr/launch/'

response = requests.get(url)

if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    ul = soup.select_one('ul.item-list-wrap')
    print(html)

else : 
    print(response.status_code)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<script src="https://ajax.googleapis.com/ajax/libs/jquery/1.8.3/jquery.min.js" type="text/javascript"></script>
# 		<script src="https://assets.adobedtm.com/33e935265ccb0d19d288448546d81ff9491b3836/satelliteLib-e3452acbf1bddc301d138b9f9b279553bff7662b.js"></script>
# 		<meta charset="UTF-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" />
# 		<title></title>
# 		<style type="text/css">
# 			@import 'https://fonts.googleapis.com/earlyaccess/notosanskr.css';
# 			/*reset*/
# 			html, body, div, span, applet, object, iframe,
# 			h1, h2, h3, h4, h5, h6, p, blockquote, pre,
# 			a, abbr, acronym, address, big, cite, code,
# 			del, dfn, em, img, ins, kbd, q, s, samp,
# 			small, strike, strong, sub, sup, tt, var,
# 			b, u, i, center,
# 			dl, dt, dd, ol, ul, li,
# 			fieldset, form, label, legend,
# 			table, caption, tbody, tfoot, thead, tr, th, td,
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://kin.naver.com/search/list.nhn?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC'

response = requests.get(url)

if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    ul = soup.select_one('ul.basic1')
    titles = ul.select('li>dl>dt>a')
    for title in titles:
        print(title.get_text())
    print(ul)
else : 
    print(response.status_code)
# Out:
# 파이썬강좌 질문있어요
# 파이썬 질문
# 파이썬 관련 질문
# 파이썬에서 enumerate 질문이요
# 파이썬 idle 코드
# 파이썬 입문 책
# 프로그래밍 언어 (자바vs 파이썬)
# 파이썬독학 하려는데..
# 파이썬 수업 후 생기부 고민
# 파이썬 3.9 numpy 모듈이 안됩니다......
# <ul class="basic1">
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=111&amp;docId=399905207&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin&amp;rank=1&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b>강좌 질문있어요</a>
# </dt>
# <dd class="txt_inline">2021.09.13.</dd>
# <dd>... 초보자는 <b>파이썬</b>강좌부터 보면 되는거 맞나요? 2. <b>파이썬</b>강좌 볼만한 곳 좀... 독학하는데 도움될만한 조언 부탁드려요  <b>파이썬</b>강좌 질문있어요 질문 1. 초보자는... </dd>
# <dd class="tag_area">
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna&amp;dirId=111">컴퓨터 자격증, 학원</a>
# ...

# %%
from selenium import webdriver
driver = webdriver.Chrome()
url = 'https://docs.google.com/forms/d/1hxMhufpH5K-KStoqUR4WOvmdJ93d30Sq5tHrlvhyD3E/viewform?edit_requested=true'
driver.implicitly_wait(3)
driver.get(url)
driver.implicitly_wait(3)
driver.find_element_by_class_name('appsMaterialWizToggleRadiogroupOffRadio').click()
driver.find_element_by_class_name('quantumWizTogglePapercheckboxInnerBox').click()
driver.find_element_by_class_name('appsMaterialWizToggleRadiogroupOffRadio').click()
driver.find_element_by_xpath('//*[@id="i38"]/div[3]/div').click()
driver.find_element_by_xpath('//*[@id="i69"]/div[3]/div').click()
driver.find_element_by_xpath('//*[@id="i127"]/div[3]/div').click()
driver.find_element_by_xpath('//*[@id="i152"]/div[3]/div').click()
driver.find_element_by_xpath('//*[@id="mG61Hd"]/div[2]/div/div[2]/div[7]/div/div/div[2]/div/div[1]/div/div[1]/input').send_keys('이름')
driver.find_element_by_xpath('//*[@id="mG61Hd"]/div[2]/div/div[2]/div[8]/div/div/div[2]/div/div[1]/div/div[1]/input').send_keys('생년월일')
driver.find_element_by_xpath('//*[@id="mG61Hd"]/div[2]/div/div[2]/div[9]/div/div/div[2]/div/div[1]/div/div[1]/input').send_keys('핸드폰번호')
driver.find_element_by_xpath('//*[@id="mG61Hd"]/div[2]/div/div[2]/div[10]/div/div/div[2]/div/div[1]/div/div[1]/input').send_keys('나이키아이디')
driver.find_element_by_xpath('//*[@id="i188"]/div[2]').click()
driver.find_element_by_xpath('//*[@id="i196"]/div[2]').click()
driver.find_element_by_xpath('//*[@id="i204"]/div[2]').click()
driver.find_element_by_xpath('//*[@id="i212"]/div[2]').click()
driver.find_element_by_xpath('//*[@id="i220"]/div[2]').click()
driver.find_element_by_xpath('//*[@id="mG61Hd"]/div[2]/div/div[3]/div[1]/div/div/span')#.click()
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="aafa9130bf2079864a22e15cb3738d09", element="e4ca318d-4f78-4eb8-af6f-6a40e7e96e2b")>

# %%
//*[@id="i53"]/div[3]/div
//*[@id="i127"]/div[3]/div/div
//*[@id="i152"]/div[3]/div

# %%
dir(driver)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_file_detector',
#  '_is_remote',
#  '_mobile',
#  '_switch_to',
#  '_unwrap_value',
#  '_web_element_cls',
#  '_wrap_value',
#  'add_cookie',
#  'application_cache',
#  'back',
#  'capabilities',
#  'close',
#  'command_executor',
#  'create_options',
#  'create_web_element',
#  'current_url',
#  'current_window_handle',
#  'delete_all_cookies',
#  'delete_cookie',
#  'desired_capabilities',
#  'error_handler',
#  'execute',
#  'execute_async_script',
#  'execute_cdp_cmd',
#  'execute_script',
#  'file_detector',
# ...

# %%
dir(driver.find_element_by_xpath)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__func__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
import requests
from bs4 import BeautifulSoup

from openpyxl import Workbook

# %%
url = 'https://finance.naver.com/'

response = requests.get(url)
response.raise_for_status()
html = response.text
soup = BeautifulSoup(html, 'html.parser')
tbody = soup.select_one('#container > div.aside > div > div.aside_area.aside_popular > table > tbody')
trs = tbody.select('tr')
print(tbody)
datas = []
for tr in trs:
    name = tr.select_one('th > a').get_text()
    current_price = tr.select_one('td').get_text()
    change_direction = tr['class'][0]
    change_price = tr.select_one('td>span').get_text()
    datas.append([name,current_price,change_direction,change_price])
    
print(datas)

write_wb = Workbook()
write_ws = write_wb.create_sheet('결과')
for data in datas:
    write_ws.append(data)
    
write_wb.save(r'test.xlsx')
# Out:
# <tbody>
# <tr class="up">
# <th scope="row"><em>1.</em><a href="/item/main.naver?code=005930" onclick="clickcr(this, 'boa.list', '005930', '1', event);">삼성전자</a></th>
# <td>77,200</td>
# <td> <img alt="상승" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" style="margin-right:4px;" width="7"/><span class="tah p11 red02"> 1,100 </span> </td>
# </tr>
# <tr class="up">
# <th scope="row"><em>2.</em><a href="/item/main.naver?code=329180" onclick="clickcr(this, 'boa.list', '329180', '2', event);">현대중공업</a></th>
# <td>111,500</td>
# <td> <img alt="상승" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" style="margin-right:4px;" width="7"/><span class="tah p11 red02"> 500 </span> </td>
# </tr>
# <tr class="down">
# <th scope="row"><em>3.</em><a href="/item/main.naver?code=035720" onclick="clickcr(this, 'boa.list', '035720', '3', event);">카카오</a></th>
# <td>119,500</td>
# ...

# %%
url = 'https://www.nike.com/kr/launch/'

response = requests.get(url)
print(response)
#response.raise_for_status()
html = response.content.decode('utf-8')
print(html)
soup = BeautifulSoup(html, 'html.parser')
table = soup.select_one('#root > div > div.container-fluid.pg-layout.pg-layout--mobile > div > div')
print(table)

datas = []
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<script src="https://ajax.googleapis.com/ajax/libs/jquery/1.8.3/jquery.min.js" type="text/javascript"></script>
# 		<script src="https://assets.adobedtm.com/33e935265ccb0d19d288448546d81ff9491b3836/satelliteLib-e3452acbf1bddc301d138b9f9b279553bff7662b.js"></script>
# 		<meta charset="UTF-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" />
# 		<title></title>
# 		<style type="text/css">
# 			@import 'https://fonts.googleapis.com/earlyaccess/notosanskr.css';
# 			/*reset*/
# 			html, body, div, span, applet, object, iframe,
# 			h1, h2, h3, h4, h5, h6, p, blockquote, pre,
# 			a, abbr, acronym, address, big, cite, code,
# 			del, dfn, em, img, ins, kbd, q, s, samp,
# 			small, strike, strong, sub, sup, tt, var,
# 			b, u, i, center,
# 			dl, dt, dd, ol, ul, li,
# 			fieldset, form, label, legend,
# ...

# %%
import requests
from bs4 import BeautifulSoup

codes = ['096530', '010130'] # 종목코드 리스트
prices = [] # 가격정보가 담길 리스트

for code in codes:
    url = 'https://finance.naver.com/item/main.nhn?code=' + code

    response = requests.get(url)
    response.raise_for_status()
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')

    today = soup.select_one('#chart_area > div.rate_info > div')
    price = today.select_one('.blind')
    prices.append(price.get_text())

print(prices)
# Out:
# ['63,500', '518,000']
